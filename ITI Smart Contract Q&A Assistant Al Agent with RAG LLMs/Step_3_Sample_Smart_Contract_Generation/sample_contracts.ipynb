# %% [markdown]
# ##  Step 3: **Create a Sample Smart Contract**
#
# A realistic sample contract is included so you can test the system immediately without uploading your own document.

# %%
SAMPLE_CONTRACT = """
SMART CONTRACT AGREEMENT - TOKEN SALE & VESTING PROTOCOL
=========================================================
Contract Version: 2.1.0 | Network: Ethereum Mainnet | Solidity: ^0.8.20
Effective Date: January 1, 2025

PREAMBLE
--------
This Smart Contract Agreement is entered into by and between AlphaChain
Technologies Inc. (Issuer) and any wallet address that interacts with this
contract (Participant). By executing any transaction with this contract,
all parties agree to be legally bound by the following terms.

ARTICLE 1 - TOKEN SPECIFICATIONS
---------------------------------
1.1 Token Name: AlphaToken (ALPHA)
1.2 Standard: ERC-20 (Ethereum Request for Comment 20)
1.3 Total Supply: 1,000,000,000 ALPHA (One Billion tokens)
1.4 Decimals: 18
1.5 Minting Policy: Fixed supply - no additional tokens can be minted after deployment.

ARTICLE 2 - TOKEN DISTRIBUTION
--------------------------------
2.1 Public Sale Allocation: 40% (400,000,000 ALPHA)
    - Available to all participants during the public sale period
    - Subject to KYC/AML verification requirements

2.2 Team & Founders: 20% (200,000,000 ALPHA)
    - 12-month cliff period before any tokens vest
    - 36-month linear vesting after the cliff
    - Enforced by on-chain vesting smart contract

2.3 Ecosystem & Development Fund: 15% (150,000,000 ALPHA)
    - Controlled by a 5-of-9 multisignature wallet
    - Quarterly disbursements approved by governance vote

2.4 Community & Rewards: 15% (150,000,000 ALPHA)
    - Distributed via staking rewards and liquidity mining

2.5 Strategic Partners & Advisors: 10% (100,000,000 ALPHA)
    - 6-month cliff with 24-month vesting thereafter

ARTICLE 3 - VESTING SCHEDULE & MECHANICS
------------------------------------------
3.1 Cliff Period: No tokens may be claimed or transferred during the cliff period.
3.2 Linear Vesting: After the cliff, tokens vest per-second:
    vestedAmount = (totalAllocation * elapsedTime) / vestingDuration
3.3 Revocation: Issuer may revoke unvested tokens upon material breach,
    fraudulent conduct, or by mutual written agreement.
3.4 Acceleration: Full vesting acceleration on Change of Control (>50% acquisition).
3.5 Transfer Restrictions: Unvested tokens cannot be transferred or pledged.

ARTICLE 4 - SALE TERMS & PRICING
----------------------------------
4.1 Pre-Sale Round:
    - Price: 0.005 USD per ALPHA
    - Minimum Purchase: 10,000 USD
    - Maximum Purchase: 500,000 USD per wallet
    - Lock-up: 6 months post-TGE (Token Generation Event)

4.2 Public Sale Round:
    - Price: 0.01 USD per ALPHA
    - Minimum Purchase: 100 USD
    - Maximum Purchase: 50,000 USD per wallet
    - Hard Cap: 4,000,000 USD
    - Soft Cap: 500,000 USD
    - Accepted Currencies: ETH, USDC, USDT

4.3 Refund Policy: If soft cap not reached, all participants receive a full refund
    processed automatically within 72 hours of sale conclusion.

4.4 Unsold Tokens: Unsold ALPHA tokens shall be burned (sent to 0x000...dead address).

ARTICLE 5 - GOVERNANCE RIGHTS
-------------------------------
5.1 Voting Power: 1 ALPHA = 1 vote.
5.2 Proposal Threshold: Minimum 1,000,000 ALPHA (0.1% of supply) to submit proposals.
5.3 Quorum: Minimum 10% of circulating supply must vote for validity.
5.4 Approval Threshold: 60% approval required for proposals to pass.
5.5 Voting Period: 7 days for standard; 48 hours for emergency proposals.
5.6 Timelock: 48-hour timelock on all approved governance actions.
5.7 Delegation: Token holders may delegate voting power without transferring tokens.

ARTICLE 6 - STAKING & REWARDS
-------------------------------
6.1 Base APY: 8% annually for standard staking.
6.2 Bonus APY: Additional 4% APY for staking periods exceeding 12 months.
6.3 Slashing: Up to 10% slash for validator downtime over 48 hours or double-signing.
6.4 Unstaking Period: 14-day unbonding period with no rewards during unbonding.
6.5 Reward Distribution: Rewards distributed every 24 hours, auto-compounded by default.

ARTICLE 7 - SECURITY & AUDIT
------------------------------
7.1 Audits: Audited by CertiK (Report: CK-2024-0892) and Trail of Bits (TOB-2024-155).
7.2 Bug Bounty: Up to 500,000 USD for critical vulnerabilities.
7.3 Upgradability: Contract is NOT upgradeable (non-proxy architecture).
7.4 Emergency Pause: 3-of-5 multisig can pause transfers for a maximum of 72 hours.
7.5 Admin Timelock: All privileged functions subject to 48-hour timelock.

ARTICLE 8 - COMPLIANCE & LEGAL
--------------------------------
8.1 KYC Requirements: Pre-sale and public sale participants must complete identity
    verification (KYC) before tokens are claimable.
8.2 Restricted Jurisdictions: Citizens/residents of the United States, Canada,
    China, North Korea, Iran, Cuba, Syria, and Sudan are prohibited from participating.
8.3 Tax Obligations: Participants solely responsible for all tax obligations.
8.4 Securities Disclaimer: ALPHA tokens are utility tokens with no equity or
    ownership rights in AlphaChain Technologies Inc.

ARTICLE 9 - DISPUTE RESOLUTION
--------------------------------
9.1 Governing Law: Laws of the Cayman Islands.
9.2 Arbitration: JAMS International Arbitration Rules.
9.3 Seat of Arbitration: Singapore.
9.4 Class Action Waiver: Participants waive right to participate in class action proceedings.

ARTICLE 10 - RISK FACTORS
---------------------------
10.1 Regulatory Risk: Changing regulations may affect token utility or transferability.
10.2 Market Risk: ALPHA value may be highly volatile; participants may lose investment.
10.3 Technology Risk: Despite auditing, smart contracts may contain vulnerabilities.
10.4 Liquidity Risk: No guarantee of a liquid market for ALPHA tokens.
10.5 Force Majeure: Issuer not liable for failures from events beyond its control.

EXECUTION
---------
Interaction with this contract constitutes acceptance of all terms herein.
Contract Deployer: 0x742d35Cc6634C0532925a3b844Bc454e4438f44e
IPFS (Full Legal Text): QmXoypizjW3WknFiJnKLwHCnL72vedxjQkDDP1mXWo6uco
"""

sample_path = Path("/content/sample_smart_contract.txt")
sample_path.write_text(SAMPLE_CONTRACT)
print(f"\u2705 Sample smart contract saved to: {sample_path}")
print(f"   Total characters: {len(SAMPLE_CONTRACT):,}")
# Out:
# ✅ Sample smart contract saved to: /content/sample_smart_contract.txt
#    Total characters: 5,985
