# %%
# Run test queries to validate the full pipeline
test_queries = [
    "What is the total token supply and token symbol?",
    "What are the vesting terms for the team and founders?",
    "How does the staking program work and what is the base APY?",
    "What happens if the soft cap is not reached?",
    "Which jurisdictions are restricted from participating in the token sale?",
]

print("=" * 70)
print("PIPELINE TEST - SAMPLE QUERIES")
print("=" * 70)

for i, query in enumerate(test_queries, 1):
    print(f"\n[Q{i}] {query}")
    print("-" * 60)
    answer, sources = rag_chain.ask(query)
    print(f"Answer:\n{answer[:500]}")
    if sources:
        print(f"\nSources:\n{sources}")
    print()
# Out:
# ...
# PIPELINE TEST - SAMPLE QUERIES
# ...
#
# [Q1] What is the total token supply and token symbol?
# ------------------------------------------------------------
# Answer:
# Based on the provided contract context:
#
# *   **Total Token Supply:** 1,000,000,000 ALPHA (One Billion tokens) - as per ARTICLE 1 - TOKEN SPECIFICATIONS, Section 1.3.
# *   **Token Symbol:** ALPHA - as per ARTICLE 1 - TOKEN SPECIFICATIONS, Section 1.1.
#
# Sources:
# **[1] sample_smart_contract.txt** · chunk 1
# ARTICLE 1 - TOKEN SPECIFICATIONS --------------------------------- 1.1 Token Name: AlphaToken (ALPHA) 1.2 Standard: ERC-20 (Ethereum Request for Comment 20) 1.3 Total Supply: 1,000...
#
# **[2] sample_smart_contract.txt** · chunk 4
# ARTICLE 4 - SALE TERMS & PRICING ---------------------------------- 4.1 Pre-Sale Round: - Price: 0.005 USD per ALPHA - Minimum Purchase: 10,000 USD - Maximum Purchase: 500,000 USD ...
#
# **[3] sample_smart_contract.txt** · chunk 2
# ...
