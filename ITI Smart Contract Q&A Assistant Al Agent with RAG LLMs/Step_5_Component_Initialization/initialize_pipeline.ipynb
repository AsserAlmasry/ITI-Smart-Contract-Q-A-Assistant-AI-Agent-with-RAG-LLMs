# %% [markdown]
# ## Step 5: **Initialize the System**

# %%
print("Initializing RAG pipeline...\n")

ingester   = DocumentIngester(chunk_size=800, chunk_overlap=150)
vsm        = VectorStoreManager(persist_directory="/content/chroma_db")
guardrails = SmartContractGuardrails()
rag_chain  = SmartContractRAGChain(vsm, guardrails, top_k=5, temperature=0.1)

print("\u2705 All components initialized!")
print()
print("  \U0001f4e5 Ingestion  : RecursiveCharacterTextSplitter (800 chars, 150 overlap)")
print("  \U0001f5c4\ufe0f  Storage    : ChromaDB @ /content/chroma_db")
print("  \U0001f50d Embeddings : Google models/embedding-001")
print("  \U0001f916 LLM        : gemini-2.5-flash-lite  (temperature=0.1)")
print("  \U0001f6e1\ufe0f  Guardrails : Input validation + output moderation")
# Out:
# Initializing RAG pipeline...
#
# Loading embedding model (first run downloads ~90MB)...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Embedding model ready.
# ✅ All components initialized!
#
#   📥 Ingestion  : RecursiveCharacterTextSplitter (800 chars, 150 overlap)
#   🗄️  Storage    : ChromaDB @ /content/chroma_db
#   🔍 Embeddings : Google models/embedding-001
#   🤖 LLM        : gemini-2.5-flash-lite  (temperature=0.1)
#   🛡️  Guardrails : Input validation + output moderation
